# %%
import pandas as pd
import os
from importlib import reload
from helpers import constants; reload(constants)
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
select_label = constants.SELECT_LABEL
intermediate_path = constants.ITM_DATA_DIR

# %%
df_posts = pd.read_pickle(intermediate_path + '/post_df.pickle')
df_posts_t = pd.read_pickle(constants.ITM_DATA_DIR + '/post_df_short.pickle')

# %%
fig = plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(121)
ax1 = df_posts[select_label].value_counts().plot(kind='bar', title='gender distribution of original dataset')
ax1.set_xlabel('Label Distribution of Original Dataset')
ax2 = fig.add_subplot(122)
ax2 = df_posts_t[select_label].value_counts().plot(kind='bar', title='gender distribution after truncation')
ax2.set_xlabel('Label Distribution after truncation')
plt.savefig('../img/gender_dist_original.png')

# %%
ax = df_posts_t[select_label].value_counts().plot(kind='bar', title='gender distribution after truncation')
ax.set_xlabel('Figure 5 - Label Distribution after truncation')
plt.savefig('../img/gender_dist_truncate.png')

# %%
tf.test.gpu_device_name()
# Out:
# ''
